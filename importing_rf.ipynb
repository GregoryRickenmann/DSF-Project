# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from preprocessing_weather import WEATHER
from preprocessing_pedestrians import PEDESTRIANS
from BO9 import BO9
from preprocessing_permits import PERMITS


df = pd.read_csv("data/deponieanlieferungen-tufentobel.csv", delimiter=';')
#preprocessing of df (tüfentobel)

#Check for missing values
missing_values = df.isna().sum()
# missing_values

#missing values are in column "Kanton" with only 94 values missing
#also, the there are no relevant outliers in these 94 values
# df[df['Kanton'].isna()].describe()

#drop missing values for Kanton
df.dropna(subset=['Kanton'], inplace=True)

#check where the anlieferungen are zero tons
df[df['Gewicht in Tonnen'] == 0].value_counts().sum()

#remove these values
df.drop(df[df['Gewicht in Tonnen'] == 0].index, inplace=True)

#test if it worked
df[df['Gewicht in Tonnen'] == 0].value_counts().sum()

#check very small values
#print(df[df['Gewicht in Tonnen'] < 0.1].value_counts().sum())

#check duplicates
duplicates = df.duplicated()
#print(f"Number of duplicate rows: {duplicates.sum()}")

# #Visualize the outliers in a plot
# plt.figure(figsize=(10, 6))
# plt.boxplot(df['Gewicht in Tonnen'], vert=False)
# plt.title('Boxplot of Gewicht in Tonnen')
# plt.xlabel('Gewicht in Tonnen')
# plt.show()


# df[df['Gewicht in Tonnen'] > 35]

#there is one outlier with 56.7 tons, the other values dont go over 35 tons
#remove this outlier
df.drop(df[df['Gewicht in Tonnen'] > 50].index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 9
#       7 from preprocessing_pedestrians import PEDESTRIANS
#       8 from BO9 import BO9
# ----> 9 from preprocessing_permits import PERMITS
#      12 df = pd.read_csv("data/deponieanlieferungen-tufentobel.csv", delimiter=';')
#      13 #preprocessing of df (tüfentobel)
#      14
#      15 #Check for missing values
#
# File ~/Documents/GitHub/DSF-Project/preprocessing_permits.py:9
#       7 import matplotlib.pyplot as plt
#       8 import seaborn as sns
# ----> 9 import chardet
#      11 # If we check the data, there are certain letters displayed as �. This is due to the data being encoded in a different way, so we have to find the encoding
#      12 with open("data/export-2024-11-27-08-46-53.csv", "rb") as file:
#
# ModuleNotFoundError: No module named 'chardet'

# %%
# Convert the date column to datetime and ensure the format is year, month, day
df['Anlieferungsdatum'] = pd.to_datetime(df['Anlieferungsdatum'], utc=True).dt.date
df = df[["Anlieferungsdatum", "Material", "Gewicht in Tonnen"]]

# %%
# merge the features pedestrians and weather with the df
merged_features = pd.merge(PEDESTRIANS, WEATHER, on='Date', how='inner')
merged_features['Date'] = pd.to_datetime(merged_features['Date'], utc=True).dt.date

# %%
# print(merged_features.head())
features = pd.merge(df, merged_features, left_on='Anlieferungsdatum', right_on="Date", how='inner')
features.head()
# Out:
#   Anlieferungsdatum                    Material  Gewicht in Tonnen  \
# 0        2021-09-20                 Inertstoffe               3.14
# 1        2021-09-20  stark verschmutzte Abfälle              21.04
# 2        2021-09-20  stark verschmutzte Abfälle              22.00
# 3        2021-09-20  stark verschmutzte Abfälle               8.12
# 4        2021-09-20                 Inertstoffe               3.38
#
#          Date  Day  Workday  Total Pedestrians    Location  Temperature mean  \
# 0  2021-09-20    1        1             2687.0  St. Gallen              10.7
# 1  2021-09-20    1        1             2687.0  St. Gallen              10.7
# 2  2021-09-20    1        1             2687.0  St. Gallen              10.7
# 3  2021-09-20    1        1             2687.0  St. Gallen              10.7
# 4  2021-09-20    1        1             2687.0  St. Gallen              10.7
#
#    Temperature max  Temperature min  Precipitation in mm  Snow amount in cm
# 0             12.8              9.0                  1.1                0.0
# 1             12.8              9.0                  1.1                0.0
# 2             12.8              9.0                  1.1                0.0
# 3             12.8              9.0                  1.1                0.0
# 4             12.8              9.0                  1.1                0.0

# %%
BO9.sort_values(by='Anlieferungsdatum', inplace=True, ascending=True)
nineteen =
# Out:
# 2019-01-01 00:00:00    False
# 2019-01-02 00:00:00    False
# 2019-01-03 00:00:00    False
# 2019-01-04 00:00:00    False
# 2019-01-05 00:00:00    False
# Name: Anlieferungsdatum, dtype: bool

# %%
# Perform a many-to-one join by merging on 'Anlieferungsdatum' and 'Date' columns
new_features = pd.merge(features, BO9, on='Anlieferungsdatum', how='left')

# Drop the redundant 'Date' column from the merged dataframe
new_features.sort_values(by='Anlieferungsdatum', inplace=True, ascending=False)
new_features.head()
# Out:
#       Anlieferungsdatum                    Material  Gewicht in Tonnen  \
# 86133        2024-02-28             Sauberer Aushub              24.40
# 71190        2024-02-28  stark verschmutzte Abfälle               3.40
# 71194        2024-02-28                 Inertstoffe               1.62
# 71196        2024-02-28                 Inertstoffe              17.16
# 71198        2024-02-28             Sauberer Aushub              23.62
#
#              Date  Day  Workday  Total Pedestrians    Location  \
# 86133  2024-02-28    3        1             1605.0  St. Gallen
# 71190  2024-02-28    3        1             1605.0  St. Gallen
# 71194  2024-02-28    3        1             1605.0  St. Gallen
# 71196  2024-02-28    3        1             1605.0  St. Gallen
# 71198  2024-02-28    3        1             1605.0  St. Gallen
#
#        Temperature mean  Temperature max  Temperature min  \
# 86133               4.1              4.8              3.4
# 71190               4.1              4.8              3.4
# 71194               4.1              4.8              3.4
# 71196               4.1              4.8              3.4
# 71198               4.1              4.8              3.4
#
#        Precipitation in mm  Snow amount in cm  Investments
# 86133                  0.0                0.0          NaN
# 71190                  0.0                0.0          NaN
# 71194                  0.0                0.0          NaN
# 71196                  0.0                0.0          NaN
# 71198                  0.0                0.0          NaN

# %%
# Drop the redundant 'Date' column from the merged dataframe
new_features.tail(20)
# Out:
#       Anlieferungsdatum                    Material  Gewicht in Tonnen  \
# 65408        2022-12-22                 Inertstoffe               4.62
# 65409        2022-12-22  stark verschmutzte Abfälle               1.90
# 65410        2022-12-22                 Inertstoffe              25.84
# 65411        2022-12-22                 Inertstoffe              21.34
# 65412        2022-12-22                 Inertstoffe              24.10
# 65413        2022-12-22                 Inertstoffe               7.48
# 65414        2022-12-22                 Inertstoffe              19.56
# 65415        2022-12-22  stark verschmutzte Abfälle               3.40
# 65416        2022-12-22                 Inertstoffe              23.40
# 65417        2022-12-22                 Inertstoffe              22.68
# 65418        2022-12-22                 Inertstoffe              26.38
# 65419        2022-12-22                 Inertstoffe               7.22
# 65420        2022-12-23                    Schlacke              22.64
# 65421        2022-12-23  stark verschmutzte Abfälle               6.84
# 65422        2022-12-23                 Inertstoffe               8.50
# 65423        2022-12-23  stark verschmutzte Abfälle               3.60
# 65424        2022-12-23  stark verschmutzte Abfälle               3.46
# 65425        2022-12-23  stark verschmutzte Abfälle              12.02
# 65426        2022-12-30                    Schlacke              22.34
# 65427        2022-12-30                    Schlacke              22.22
#
#              Date  Day  Workday  Total Pedestrians    Location  \
# 65408  2022-12-22    4        1             3152.0  St. Gallen
# 65409  2022-12-22    4        1             3152.0  St. Gallen
# 65410  2022-12-22    4        1             3152.0  St. Gallen
# 65411  2022-12-22    4        1             3152.0  St. Gallen
# 65412  2022-12-22    4        1             3152.0  St. Gallen
# 65413  2022-12-22    4        1             3152.0  St. Gallen
# 65414  2022-12-22    4        1             3152.0  St. Gallen
# 65415  2022-12-22    4        1             3152.0  St. Gallen
# 65416  2022-12-22    4        1             3152.0  St. Gallen
# 65417  2022-12-22    4        1             3152.0  St. Gallen
# 65418  2022-12-22    4        1             3152.0  St. Gallen
# 65419  2022-12-22    4        1             3152.0  St. Gallen
# 65420  2022-12-23    5        1             3145.0  St. Gallen
# 65421  2022-12-23    5        1             3145.0  St. Gallen
# 65422  2022-12-23    5        1             3145.0  St. Gallen
# 65423  2022-12-23    5        1             3145.0  St. Gallen
# 65424  2022-12-23    5        1             3145.0  St. Gallen
# 65425  2022-12-23    5        1             3145.0  St. Gallen
# 65426  2022-12-30    5        1             2529.0  St. Gallen
# 65427  2022-12-30    5        1             2529.0  St. Gallen
#
#        Temperature mean  Temperature max  Temperature min  \
# 65408               9.0             11.1              7.1
# 65409               9.0             11.1              7.1
# 65410               9.0             11.1              7.1
# 65411               9.0             11.1              7.1
# 65412               9.0             11.1              7.1
# 65413               9.0             11.1              7.1
# 65414               9.0             11.1              7.1
# 65415               9.0             11.1              7.1
# 65416               9.0             11.1              7.1
# 65417               9.0             11.1              7.1
# 65418               9.0             11.1              7.1
# 65419               9.0             11.1              7.1
# 65420              10.1             11.4              9.1
# 65421              10.1             11.4              9.1
# 65422              10.1             11.4              9.1
# 65423              10.1             11.4              9.1
# 65424              10.1             11.4              9.1
# 65425              10.1             11.4              9.1
# 65426               6.7             12.5              1.9
# 65427               6.7             12.5              1.9
#
#        Precipitation in mm  Snow amount in cm  Investments
# 65408                  0.8                0.0          0.0
# 65409                  0.8                0.0          0.0
# 65410                  0.8                0.0          0.0
# 65411                  0.8                0.0          0.0
# 65412                  0.8                0.0          0.0
# 65413                  0.8                0.0          0.0
# 65414                  0.8                0.0          0.0
# 65415                  0.8                0.0          0.0
# 65416                  0.8                0.0          0.0
# 65417                  0.8                0.0          0.0
# 65418                  0.8                0.0          0.0
# 65419                  0.8                0.0          0.0
# 65420                 12.1                0.0          0.0
# 65421                 12.1                0.0          0.0
# 65422                 12.1                0.0          0.0
# 65423                 12.1                0.0          0.0
# 65424                 12.1                0.0          0.0
# 65425                 12.1                0.0          0.0
# 65426                  0.4                0.0          0.0
# 65427                  0.4                0.0          0.0

# %%
PERMITS.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 PERMITS.head()
#
# NameError: name 'PERMITS' is not defined
